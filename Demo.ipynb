# %% [markdown]
# # Convolutional CRFs for Semantic Segmentation

# %% [markdown]
# ### Load Images

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
from demo import synthetic
import imageio
import matplotlib.pyplot as plt

IMG = 'data/img_bicycle.png'
LABELS = 'data/img_bicycle_labels.png'
image = imageio.imread(IMG)
labels = imageio.imread(LABELS)

# %%
unary = synthetic.augment_label(labels, num_classes=21)
type(unary)
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# numpy.ndarray

# %%
from dotmap import DotMap

args = DotMap()
args.pyinn = False
args.nospeed = True 
args.output = None

# %%
from demo import do_crf_inference, plot_results
prediction = do_crf_inference(image, unary, args)
# Out:
# 2018-10-22 17:16:49,592 INFO Build ConvCRF.
# 2018-10-22 17:16:49,596 INFO Start Computation.
# 2018-10-22 17:16:49,635 INFO Doing speed evaluation.
# 2018-10-22 17:16:50,037 INFO Finished running 10 predictions.
# 2018-10-22 17:16:50,039 INFO Avg. Computation time: 40.160202980041504 ms
# (1, 21, 500, 334)

# %%
prediction.shape, labels.shape
# Out:
# ((1, 21, 500, 334), (500, 334))

# %%
plot_results(image, unary, prediction, labels, args)
# Out:
# 2018-10-22 16:31:18,705 INFO Plot results.
